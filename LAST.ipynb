# %% [markdown]
# <a href="https://colab.research.google.com/github/ishashende/python/blob/master/LAST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df= pd.read_csv("/content/drive/My Drive/ train.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format='retina'

# %%
sns.countplot(x='Survived',data=df)

# %%
sns.countplot(x='Survived',data=df,hue='Sex')

# %%
sns.lineplot(x='Age',y='Fare',data=df)

# %%
df.plot.scatter('Age','Fare')

# %%
df.plot.scatter('Age','Survived')

# %%
df['Age'].hist(bins=8)

# %%
import matplotlib.pyplot as plt
sizes= df['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived',
'Survived'],autopct='%1.1f%%',shadow=True)
plt.show()
